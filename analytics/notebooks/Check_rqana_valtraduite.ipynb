# %% [markdown]
# # Check du lien et des valeurs

# %%
# %load_ext sql
# %sql duckdb:///../../database/data.duckdb
# %config SqlMagic.displaylimit = 100
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT
#    *
# FROM
#     edc_resultats
# LIMIT 2
# Out:
# Running query in 'duckdb:///../../database/data.duckdb'
# +--------+---------------+---------------------+-------------+--------------------+--------------------+-----------------+-------------+-----------+--------+--------------------------+------------------+------------+---------+-------------+-----------+--------------+--------------+-------------------+---------------------+
# | cddept | referenceprel | cdparametresiseeaux | cdparametre |  libmajparametre   |  libminparametre   | libwebparametre | qualitparam | insituana | rqana  | cdunitereferencesiseeaux | cdunitereference | limitequal | refqual | valtraduite |  casparam | referenceanl | de_partition | de_ingestion_date | de_dataset_datetime |
# ...

# %%
# %%sql
# SELECT DISTINCT
#     valtraduite,
#     rqana
# FROM
#     edc_resultats
# WHERE
#     valtraduite =0 OR valtraduite=1
# Out:
# Running query in 'duckdb:///../../database/data.duckdb'
# +-------------+----------------+
# | valtraduite |     rqana      |
# +-------------+----------------+
# |     0.0     |    <0,0050     |
# |     0.0     |     <0,050     |
# |     0.0     |       <5       |
# |     0.0     |     <0,500     |
# |     0.0     |     <0,100     |
# |     0.0     |      0,00      |
# |     0.0     | Aspect normal  |
# |     1.0     | Aspect anormal |
# |     0.0     |     <8,60      |
# |     0.0     |     <0,001     |
# |     0.0     |     <0,048     |
# |     0.0     |     <3,70      |
# |     0.0     |     <3,40      |
# |     0.0     |     <0,018     |
# |     0.0     |     <0,046     |
# |     0.0     |     <7,50      |
# |     0.0     |     <7,80      |
# |     0.0     |     <5,60      |
# |     0.0     |     <4,50      |
# |     0.0     |     <0,043     |
# |     0.0     |     <7,00      |
# |     0.0     |     <6,30      |
# |     0.0     |     <9,00      |
# ...

# %%
# %%sql
# SELECT DISTINCT
#     valtraduite,
#     rqana
# FROM
#     edc_resultats
# WHERE
#     valtraduite=1
# Out:
# Running query in 'duckdb:///../../database/data.duckdb'
# +-------------+------------------------------------+
# | valtraduite |               rqana                |
# +-------------+------------------------------------+
# |     1.0     |           Aspect anormal           |
# |     1.0     |                OUI                 |
# |     1.0     |              PRESENCE              |
# |     1.0     |                >1,0                |
# |     1.0     |                 1,                 |
# |     1.0     | Présence d'un dispositif de trait. |
# |     1.0     |    Branchement public en plomb     |
# |     1.0     |       Légèrement incrustante       |
# |     1.0     |                1,00                |
# |     1.0     |               1,000                |
# |     1.0     |      Présence cyanobactéries       |
# |     1.0     |  Canalisation intérieure en plomb  |
# |     1.0     |                 1                  |
# |     1.0     |         Changement anormal         |
# ...

# %%
# %%sql
# SELECT DISTINCT
#     valtraduite,
#     rqana
# FROM
#     edc_resultats
# Out:
# Running query in 'duckdb:///../../database/data.duckdb'
# +-------------+---------------+
# | valtraduite |     rqana     |
# +-------------+---------------+
# |     0.0     |     <0,050    |
# |    37.23    |     37,23     |
# |     0.0     |     <0,100    |
# |     0.05    |     0,050     |
# |     0.0     | Aspect normal |
# |     89.9    |      89,9     |
# |    565.0    |      565      |
# |     0.17    |      0,17     |
# |     8.1     |      8,1      |
# |     0.2     |      0,2      |
# |     0.78    |      0,78     |
# |     0.11    |      0,11     |
# |     1.6     |      1,6      |
# |     0.0     |     <0,500    |
# |     0.8     |      0,80     |
# |     0.7     |      0,7      |
# |     1.4     |      1,4      |
# |     7.7     |      7,7      |
# |     18.2    |      18,2     |
# |     1.38    |      1,38     |
# |    0.129    |     0,129     |
# |    120.6    |     120,6     |
# |    754.0    |      754      |
# |     14.8    |      14,8     |
# ...
